# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
# Out:
# Using TensorFlow backend.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
"""
# 載入 Callbacks, 並將監控目標設為 validation loss
"""
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint('model.h5', 
                             monitor="val_loss",
                             verbose=1,
                             save_best_only=True)

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_model("model.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 2.1613 - accuracy: 0.2832 - val_loss: 2.0847 - val_accuracy: 0.2404
#
# Epoch 00001: val_loss improved from inf to 2.08475, saving model to model.h5
# Epoch 2/50
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.7294 - accuracy: 0.3989 - val_loss: 1.9335 - val_accuracy: 0.3207
#
# Epoch 00002: val_loss improved from 2.08475 to 1.93349, saving model to model.h5
# Epoch 3/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.6071 - accuracy: 0.4385 - val_loss: 1.8135 - val_accuracy: 0.3715
#
# Epoch 00003: val_loss improved from 1.93349 to 1.81352, saving model to model.h5
# Epoch 4/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.5339 - accuracy: 0.4639 - val_loss: 1.7068 - val_accuracy: 0.4031
#
# Epoch 00004: val_loss improved from 1.81352 to 1.70680, saving model to model.h5
# Epoch 5/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.4824 - accuracy: 0.4838 - val_loss: 1.6434 - val_accuracy: 0.4258
#
# Epoch 00005: val_loss improved from 1.70680 to 1.64343, saving model to model.h5
# Epoch 6/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 1.4357 - accuracy: 0.4994 - val_loss: 1.5785 - val_accuracy: 0.4471
#
# Epoch 00006: val_loss improved from 1.64343 to 1.57849, saving model to model.h5
# Epoch 7/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.3979 - accuracy: 0.5142 - val_loss: 1.5489 - val_accuracy: 0.4568
#
# Epoch 00007: val_loss improved from 1.57849 to 1.54890, saving model to model.h5
# Epoch 8/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.3624 - accuracy: 0.5243 - val_loss: 1.5210 - val_accuracy: 0.4613
#
# Epoch 00008: val_loss improved from 1.54890 to 1.52101, saving model to model.h5
# Epoch 9/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.3283 - accuracy: 0.5391 - val_loss: 1.5052 - val_accuracy: 0.4703
#
# Epoch 00009: val_loss improved from 1.52101 to 1.50517, saving model to model.h5
# Epoch 10/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 1.2987 - accuracy: 0.5508 - val_loss: 1.4857 - val_accuracy: 0.4771
#
# Epoch 00010: val_loss improved from 1.50517 to 1.48573, saving model to model.h5
# Epoch 11/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.2702 - accuracy: 0.5590 - val_loss: 1.4838 - val_accuracy: 0.4794
#
# Epoch 00011: val_loss improved from 1.48573 to 1.48384, saving model to model.h5
# Epoch 12/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.2435 - accuracy: 0.5708 - val_loss: 1.4702 - val_accuracy: 0.4778
#
# Epoch 00012: val_loss improved from 1.48384 to 1.47024, saving model to model.h5
# Epoch 13/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.2180 - accuracy: 0.5803 - val_loss: 1.4660 - val_accuracy: 0.4831
#
# Epoch 00013: val_loss improved from 1.47024 to 1.46599, saving model to model.h5
# Epoch 14/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 1.1929 - accuracy: 0.5900 - val_loss: 1.4643 - val_accuracy: 0.4887
#
# Epoch 00014: val_loss improved from 1.46599 to 1.46427, saving model to model.h5
# Epoch 15/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.1690 - accuracy: 0.5976 - val_loss: 1.4647 - val_accuracy: 0.4878
#
# Epoch 00015: val_loss did not improve from 1.46427
# Epoch 16/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.1474 - accuracy: 0.6061 - val_loss: 1.4740 - val_accuracy: 0.4849
#
# Epoch 00016: val_loss did not improve from 1.46427
# Epoch 17/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 1.1227 - accuracy: 0.6154 - val_loss: 1.4671 - val_accuracy: 0.4831
#
# Epoch 00017: val_loss did not improve from 1.46427
# Epoch 18/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.1006 - accuracy: 0.6240 - val_loss: 1.4611 - val_accuracy: 0.4865
#
# Epoch 00018: val_loss improved from 1.46427 to 1.46113, saving model to model.h5
# Epoch 19/50
# 50000/50000 [==============================] - 6s 129us/step - loss: 1.0800 - accuracy: 0.6323 - val_loss: 1.4612 - val_accuracy: 0.4879
#
# Epoch 00019: val_loss did not improve from 1.46113
# Epoch 20/50
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.0570 - accuracy: 0.6403 - val_loss: 1.4586 - val_accuracy: 0.4939
#
# Epoch 00020: val_loss improved from 1.46113 to 1.45860, saving model to model.h5
# Epoch 21/50
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.0355 - accuracy: 0.6502 - val_loss: 1.4612 - val_accuracy: 0.4867
#
# Epoch 00021: val_loss did not improve from 1.45860
# Epoch 22/50
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.0160 - accuracy: 0.6545 - val_loss: 1.4669 - val_accuracy: 0.4858
#
# Epoch 00022: val_loss did not improve from 1.45860
# Epoch 23/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.9940 - accuracy: 0.6630 - val_loss: 1.4668 - val_accuracy: 0.4942
#
# Epoch 00023: val_loss did not improve from 1.45860
# Epoch 24/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.9727 - accuracy: 0.6724 - val_loss: 1.4628 - val_accuracy: 0.4942
#
# Epoch 00024: val_loss did not improve from 1.45860
# Epoch 25/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.9512 - accuracy: 0.6809 - val_loss: 1.4716 - val_accuracy: 0.4921
#
# Epoch 00025: val_loss did not improve from 1.45860
# Epoch 26/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.9317 - accuracy: 0.6870 - val_loss: 1.4753 - val_accuracy: 0.4943
#
# Epoch 00026: val_loss did not improve from 1.45860
# Epoch 27/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 0.9103 - accuracy: 0.6956 - val_loss: 1.4921 - val_accuracy: 0.4861
#
# Epoch 00027: val_loss did not improve from 1.45860
# Epoch 28/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.8912 - accuracy: 0.7029 - val_loss: 1.4805 - val_accuracy: 0.4974
#
# Epoch 00028: val_loss did not improve from 1.45860
# Epoch 29/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.8713 - accuracy: 0.7103 - val_loss: 1.4858 - val_accuracy: 0.4914
#
# Epoch 00029: val_loss did not improve from 1.45860
# Epoch 30/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.8533 - accuracy: 0.7191 - val_loss: 1.4986 - val_accuracy: 0.4940
#
# Epoch 00030: val_loss did not improve from 1.45860
# Epoch 31/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.8320 - accuracy: 0.7269 - val_loss: 1.4925 - val_accuracy: 0.4901
#
# Epoch 00031: val_loss did not improve from 1.45860
# Epoch 32/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.8143 - accuracy: 0.7345 - val_loss: 1.5094 - val_accuracy: 0.4952
#
# Epoch 00032: val_loss did not improve from 1.45860
# Epoch 33/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 0.7939 - accuracy: 0.7413 - val_loss: 1.5136 - val_accuracy: 0.4948
#
# Epoch 00033: val_loss did not improve from 1.45860
# Epoch 34/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.7753 - accuracy: 0.7486 - val_loss: 1.5195 - val_accuracy: 0.4937
#
# Epoch 00034: val_loss did not improve from 1.45860
# Epoch 35/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.7557 - accuracy: 0.7579 - val_loss: 1.5298 - val_accuracy: 0.4964
#
# Epoch 00035: val_loss did not improve from 1.45860
# Epoch 36/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.7369 - accuracy: 0.7636 - val_loss: 1.5303 - val_accuracy: 0.4979
#
# Epoch 00036: val_loss did not improve from 1.45860
# Epoch 37/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.7154 - accuracy: 0.7739 - val_loss: 1.5543 - val_accuracy: 0.4922
#
# Epoch 00037: val_loss did not improve from 1.45860
# Epoch 38/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.7000 - accuracy: 0.7789 - val_loss: 1.5445 - val_accuracy: 0.4940
#
# Epoch 00038: val_loss did not improve from 1.45860
# Epoch 39/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.6811 - accuracy: 0.7850 - val_loss: 1.5596 - val_accuracy: 0.4964
#
# Epoch 00039: val_loss did not improve from 1.45860
# Epoch 40/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.6617 - accuracy: 0.7944 - val_loss: 1.5677 - val_accuracy: 0.4879
#
# Epoch 00040: val_loss did not improve from 1.45860
# Epoch 41/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.6440 - accuracy: 0.8002 - val_loss: 1.5871 - val_accuracy: 0.4867
#
# Epoch 00041: val_loss did not improve from 1.45860
# Epoch 42/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.6272 - accuracy: 0.8071 - val_loss: 1.6045 - val_accuracy: 0.4888
#
# Epoch 00042: val_loss did not improve from 1.45860
# Epoch 43/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.6086 - accuracy: 0.8166 - val_loss: 1.6023 - val_accuracy: 0.4863
#
# Epoch 00043: val_loss did not improve from 1.45860
# Epoch 44/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.5921 - accuracy: 0.8217 - val_loss: 1.6165 - val_accuracy: 0.4882
#
# Epoch 00044: val_loss did not improve from 1.45860
# Epoch 45/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 0.5738 - accuracy: 0.8298 - val_loss: 1.6381 - val_accuracy: 0.4944
#
# Epoch 00045: val_loss did not improve from 1.45860
# Epoch 46/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 0.5562 - accuracy: 0.8370 - val_loss: 1.6350 - val_accuracy: 0.4874
#
# Epoch 00046: val_loss did not improve from 1.45860
# Epoch 47/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 0.5413 - accuracy: 0.8414 - val_loss: 1.6684 - val_accuracy: 0.4847
#
# Epoch 00047: val_loss did not improve from 1.45860
# Epoch 48/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.5229 - accuracy: 0.8501 - val_loss: 1.6688 - val_accuracy: 0.4923
#
# Epoch 00048: val_loss did not improve from 1.45860
# Epoch 49/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.5049 - accuracy: 0.8585 - val_loss: 1.6692 - val_accuracy: 0.4907
#
# Epoch 00049: val_loss did not improve from 1.45860
# Epoch 50/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.4900 - accuracy: 0.8629 - val_loss: 1.6807 - val_accuracy: 0.4930
#
# Epoch 00050: val_loss did not improve from 1.45860
# 10000/10000 [==============================] - 1s 109us/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
